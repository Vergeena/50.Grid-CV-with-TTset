# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset=dataset.astype(int)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independent
# Out:
#       age  bmi  children  sex_male  smoker_yes
# 0      19   27         0         0           1
# 1      18   33         1         1           0
# 2      28   33         3         1           0
# 3      33   22         0         1           0
# 4      32   28         0         1           0
# ...   ...  ...       ...       ...         ...
# 1333   50   30         3         1           0
# 1334   18   31         0         0           0
# 1335   18   36         0         0           0
# 1336   21   25         0         0           0
# 1337   61   29         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#       charges
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
# ...       ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],'splitter':['best', 'random'],
           'max_features':['sqrt', 'log2']}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter{'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005962      0.003536         0.005699        0.005236
# 1        0.003533      0.006112         0.003125        0.006250
# 2        0.005496      0.003722         0.000000        0.000000
# 3        0.003560      0.004259         0.001068        0.002137
# 4        0.004727      0.005789         0.001004        0.001230
# 5        0.006262      0.007669         0.000000        0.000000
# 6        0.003121      0.006243         0.003150        0.004034
# 7        0.007291      0.001479         0.001396        0.001143
# 8        0.013268      0.003044         0.000000        0.000000
# 9        0.016150      0.010562         0.003266        0.006531
# 10       0.015511      0.002099         0.003125        0.006250
# 11       0.015508      0.000251         0.003125        0.006250
# 12       0.000726      0.001452         0.008532        0.007073
# 13       0.006250      0.007655         0.000000        0.000000
# 14       0.003125      0.006251         0.003125        0.006250
# 15       0.001325      0.002650         0.003684        0.006068
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.471744
# 1   {'criterion': 'squared_error', 'max_features':...           0.592643
# 2   {'criterion': 'squared_error', 'max_features':...           0.666687
# 3   {'criterion': 'squared_error', 'max_features':...           0.725276
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.689304
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.719107
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.776647
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.532876
# 8   {'criterion': 'absolute_error', 'max_features'...           0.776371
# 9   {'criterion': 'absolute_error', 'max_features'...           0.675430
# 10  {'criterion': 'absolute_error', 'max_features'...           0.454028
# 11  {'criterion': 'absolute_error', 'max_features'...           0.762744
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.705039
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.739803
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.767972
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.652074
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.619415           0.546230           0.702437
# 1            0.628603           0.591965           0.554480
# 2            0.672624           0.653749           0.568937
# 3            0.563655           0.627750           0.576974
# 4            0.571986           0.594649           0.569819
# 5            0.543446           0.576410           0.514452
# 6            0.575526           0.590781           0.480649
# 7            0.617589           0.491536           0.711475
# 8            0.620011           0.637554           0.544387
# 9            0.634368           0.598573           0.665479
# 10           0.694745           0.609014           0.673971
# 11           0.628758           0.595670           0.555477
# 12           0.643561           0.639983           0.644858
# 13           0.446971           0.587353           0.472781
# 14           0.641473           0.659030           0.622627
# 15           0.488725           0.668567           0.607721
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.494815         0.566928        0.084624               15
# 1            0.464353         0.566409        0.056155               16
# 2            0.652198         0.642839        0.037746                4
# 3            0.485647         0.595861        0.079128                9
# 4            0.550424         0.595236        0.049079               10
# 5            0.613590         0.593401        0.071031               12
# 6            0.506265         0.585974        0.103861               13
# 7            0.616804         0.594056        0.076304               11
# 8            0.613637         0.638392        0.075930                5
# 9            0.650124         0.644795        0.026981                3
# 10           0.646438         0.615639        0.085757                7
# 11           0.643939         0.637318        0.069687                6
# 12           0.715928         0.669874        0.033374                1
# 13           0.628593         0.575101        0.106794               14
# 14           0.628893         0.663999        0.053454                2
# 15           0.610786         0.605574        0.062954                8

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=float(input("Sex_Male 0 or 1:"))
smoker_yes_input=float(input("Smoker_Yes 0 or 1:"))
# Out:
# Age:29
# BMI:34
# Children:1
# Sex_Male 0 or 1:0
# Smoker_Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[49577.]
